# %%
# 1. Check number is prime or not
def check_p(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

print(check_p(17))

# %%
# 2. Sum of prime numbers in list
def check_p(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5) + 1):
        if num % i == 0:
            return False
    return True

lst = [1,3,6,19,17,49,24,29,28,26,14,17]
total = 0
for i in lst:
    if check_p(i):
        total += i
print(total)

# %%
# 3. Factorial
def fact(num):
    result = 1
    for i in range(1, num + 1):
        result *= i
    print('Factorial is:', result)

n = int(input('Enter number: '))
fact(n)

# %%
# 4. Fibonacci Series
def fibo(num):
    n1, n2 = 0, 1
    for i in range(num):
        print(n1)
        n1, n2 = n2, n1 + n2

n = int(input('Enter number: '))
fibo(n)

# %%
# 5. Reverse Number
def reverse(num):
    rev = 0
    while num > 0:
        rem = num % 10
        rev = rev * 10 + rem
        num = num // 10
    return rev

n = int(input('Enter number: '))
print('Reverse:', reverse(n))

# %%
# 6. Palindrome Number
def palindrome(num):
    temp = num
    rev = 0
    while num > 0:
        rem = num % 10
        rev = rev * 10 + rem
        num = num // 10
    if temp == rev:
        print('Palindrome number')
    else:
        print('Not palindrome')

n = int(input('Enter number: '))
palindrome(n)

# %%
# 7. Perfect Number
def perfect(num):
    total = 0
    for i in range(1, num):
        if num % i == 0:
            total += i
    if total == num:
        print(num, 'is a Perfect number')
    else:
        print(num, 'is not a Perfect number')

n = int(input('Enter number: '))
perfect(n)
